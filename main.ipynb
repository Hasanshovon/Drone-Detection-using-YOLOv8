# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
import yaml
import glob
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#sns.set_theme(style="darkgrid", font_scale=1.5, font="SimHei", rc={"axes.unicode_minus":False})

import torch
from ultralytics import YOLO

from PIL import Image

seed = 1
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)

# %%
model = YOLO("yolov8n.pt")

# %%
import os 
# get the current directory path 
path = os.getcwd()
path
# Out:
# 'd:\\Tampere University\\Ms in CSE\\Year 2023-2024\\RA\\work progress\\kaggle\\1. yolo drone detection\\archive\\drone_dataset'

# %%
# how to train the model on gpu
results = model.train(data="data.yaml", epochs=5, save_period=10,device="0",seed=seed)

#results = model.train(data="data.yaml", epochs=3, save_period=10,seed=seed)
# Out:
# New https://pypi.org/project/ultralytics/8.2.79 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.30  Python-3.11.5 torch-2.2.0 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
metrics = model.val()
# Out:
# Ultralytics YOLOv8.2.30  Python-3.11.5 torch-2.2.0 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning D:\Tampere University\Ms in CSE\Year 2023-2024\RA\work progress\kaggle\1. yolo drone detection\archive\drone_dataset\valid\labels.cache... 347 images, 0 backgrounds, 0 corrupt: 100%|██████████| 347/347 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 22/22 [00:08<00:00,  2.58it/s]
#                    all        347        369      0.842      0.739      0.794      0.397
# Speed: 0.9ms preprocess, 9.1ms inference, 0.0ms loss, 2.6ms postprocess per image
# Results saved to runs\detect\train82

# %%
print(metrics.box.map)

# %%
import glob
paths = glob.glob("D:/Tampere University/Ms in CSE/Year 2023-2024/RA/work progress/kaggle/1. yolo drone detection/archive/drone_dataset/valid/images/*")

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
# Assuming 'model' and 'paths' are already defined
n = 3
results = model.predict(paths[:n])

for i in range(n):
    r = results[i]
    plot_array = r.plot()  # Assuming r.plot() returns a numpy array
    print(plot_array.shape)
    #img = Image.fromarray(plot_array)
    
    plt.figure(figsize=(10, 10))
    plt.imshow(plot_array)
    plt.axis("off")
    plt.tight_layout()
    plt.show()
# Out:
# 0: 640x640 4 drones, 96.2ms
# 1: 640x640 1 drone, 96.2ms
# 2: 640x640 1 drone, 96.2ms
# Speed: 10.3ms preprocess, 96.2ms inference, 27.6ms postprocess per image at shape (1, 3, 640, 640)
# (400, 900, 3)
# (1334, 2000, 3)
# (1334, 2000, 3)

# %%
#save the model
model.save("yolov8n_drone.pt")

# %%
model = YOLO("yolov8n_drone.pt")

# %%
import cv2

# Load the video
video_path = 'cam1.mp4'
cap = cv2.VideoCapture(video_path)

# Check if video opened successfully
if not cap.isOpened():
    print("Error: Could not open video.")
    exit()

# Process each frame
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Preprocess the frame as required by your model
    # For example, resize and normalize
    input_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Perform detection
    results = model.predict(input_frame)
    results =  results[0].plot()
    # Post-process the results and draw bounding boxes
    
    #frame_with_detections = postprocess_results(frame, results)

    # Display the frame with detections
    #cv2.imshow('Drone Detection', frame_with_detections)
    cv2.imshow('Drone Detection',results)
    # Press 'q' to exit the video display
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture object and close display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 drone, 36.0ms
# Speed: 9.0ms preprocess, 36.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 drone, 35.5ms
# Speed: 9.1ms preprocess, 35.5ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 drone, 37.0ms
# Speed: 9.0ms preprocess, 37.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 drone, 45.0ms
# Speed: 8.0ms preprocess, 45.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 drone, 37.0ms
# Speed: 11.0ms preprocess, 37.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 drone, 36.0ms
# Speed: 7.0ms preprocess, 36.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 drone, 37.0ms
# Speed: 7.0ms preprocess, 37.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 drone, 35.0ms
# ...
